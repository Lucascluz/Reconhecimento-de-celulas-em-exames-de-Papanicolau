# %%
# %pip install pandas
# %pip install opencv-python
# Out:
# Requirement already satisfied: pandas in c:\python\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\python\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\python\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in c:\python\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\python\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import builtins
import cv2
import os

import pandas as pd

# %%
input_folder = "images"
output_folder = "sub_images"

# Criar o diretório de saída se não existir
if not os.path.exists(output_folder):
        os.makedirs(output_folder)

# %%
# Carregar o arquivo CSV com as coordenadas dos núcleos
csv_file = "classifications.csv"
df = pd.read_csv(csv_file)

# %%
#Itera sobre "characters.csv" e direciona cada núcleo recortado para o sub-diretório adequado
for index, row in df.iterrows():
        # Obter o caminho completo da imagem
        image_path = os.path.join(input_folder, row['image_filename'])

        # Verificar se a imagem existe
        if not os.path.exists(image_path):
            builtins.print(f"Imagem não encontrada: {image_path}") # type: ignore
            continue

        # Carregar a imagem
        image = cv2.imread(image_path)

        # Verificar se a imagem foi carregada com sucesso
        if image is None:
            print(f"Erro ao carregar a imagem: {image_path}")
            continue

        # Obter as coordenadas do núcleo
        x, y = int(row['nucleus_x']), int(row['nucleus_y'])

        # Verificar se as coordenadas estão dentro dos limites da imagem
        if x - 50 < 0 or y - 50 < 0 or x + 50 >= image.shape[1] or y + 50 >= image.shape[0]:
            print(f"Coordenadas inválidas para a imagem: {row['image_id']} na célula {row['cell_id']}")
            continue

        # Definir a região de interesse (ROI) para cortar a imagem
        roi = image[y-50:y+50, x-50:x+50]

        # Criar o diretório da classe (bethesda_system) se não existir
        class_folder = os.path.join(output_folder, str(row['bethesda_system']))
        if not os.path.exists(class_folder):
            os.makedirs(class_folder)

        # Construir o nome do arquivo para a subimagem
        file_name = f"{row['cell_id']}.png"

        # Construir o caminho completo de saída
        output_path = os.path.join(class_folder, file_name)

        # Redimensionar a imagem para 100x100 pixels
        roi_resized = cv2.resize(roi, (100, 100))

        # Salvar a imagem cortada no diretório de saída
        cv2.imwrite(output_path, roi_resized)
# Out:
# Coordenadas inválidas para a imagem: 398 na célula 91
# Coordenadas inválidas para a imagem: 398 na célula 92
# Coordenadas inválidas para a imagem: 398 na célula 100
# Coordenadas inválidas para a imagem: 392 na célula 546
# Coordenadas inválidas para a imagem: 391 na célula 581
# Coordenadas inválidas para a imagem: 391 na célula 582
# Coordenadas inválidas para a imagem: 391 na célula 585
# Coordenadas inválidas para a imagem: 391 na célula 586
# Coordenadas inválidas para a imagem: 389 na célula 698
# Coordenadas inválidas para a imagem: 389 na célula 699
# Coordenadas inválidas para a imagem: 389 na célula 710
# Coordenadas inválidas para a imagem: 387 na célula 763
# Coordenadas inválidas para a imagem: 387 na célula 767
# Coordenadas inválidas para a imagem: 387 na célula 789
# Coordenadas inválidas para a imagem: 387 na célula 790
# Coordenadas inválidas para a imagem: 387 na célula 798
# Coordenadas inválidas para a imagem: 387 na célula 803
# Coordenadas inválidas para a imagem: 385 na célula 823
# Coordenadas inválidas para a imagem: 384 na célula 912
# Coordenadas inválidas para a imagem: 384 na célula 934
# Coordenadas inválidas para a imagem: 382 na célula 960
# Coordenadas inválidas para a imagem: 382 na célula 967
# Coordenadas inválidas para a imagem: 382 na célula 968
# Coordenadas inválidas para a imagem: 382 na célula 974
# Coordenadas inválidas para a imagem: 378 na célula 1006
# Coordenadas inválidas para a imagem: 378 na célula 1009
# Coordenadas inválidas para a imagem: 378 na célula 1014
# Coordenadas inválidas para a imagem: 378 na célula 1023
# Coordenadas inválidas para a imagem: 378 na célula 1037
# Coordenadas inválidas para a imagem: 376 na célula 1047
# Coordenadas inválidas para a imagem: 373 na célula 1092
# Coordenadas inválidas para a imagem: 373 na célula 1105
# Coordenadas inválidas para a imagem: 371 na célula 1139
# Coordenadas inválidas para a imagem: 371 na célula 1140
# Coordenadas inválidas para a imagem: 371 na célula 1142
# Coordenadas inválidas para a imagem: 371 na célula 1163
# Coordenadas inválidas para a imagem: 371 na célula 1176
# Coordenadas inválidas para a imagem: 371 na célula 1177
# Coordenadas inválidas para a imagem: 371 na célula 1178
# Coordenadas inválidas para a imagem: 371 na célula 1179
# Coordenadas inválidas para a imagem: 371 na célula 1187
# Coordenadas inválidas para a imagem: 371 na célula 1194
# Coordenadas inválidas para a imagem: 371 na célula 1195
# Coordenadas inválidas para a imagem: 371 na célula 1201
# Coordenadas inválidas para a imagem: 371 na célula 1202
# Coordenadas inválidas para a imagem: 371 na célula 1211
# Coordenadas inválidas para a imagem: 371 na célula 1219
# Coordenadas inválidas para a imagem: 371 na célula 1220
# Coordenadas inválidas para a imagem: 371 na célula 1225
# Coordenadas inválidas para a imagem: 371 na célula 1227
# Coordenadas inválidas para a imagem: 368 na célula 1264
# Coordenadas inválidas para a imagem: 367 na célula 1274
# Coordenadas inválidas para a imagem: 367 na célula 1275
# Coordenadas inválidas para a imagem: 367 na célula 1276
# Coordenadas inválidas para a imagem: 367 na célula 1286
# Coordenadas inválidas para a imagem: 366 na célula 1296
# Coordenadas inválidas para a imagem: 366 na célula 1297
# Coordenadas inválidas para a imagem: 366 na célula 1298
# Coordenadas inválidas para a imagem: 366 na célula 1300
# Coordenadas inválidas para a imagem: 366 na célula 1306
# Coordenadas inválidas para a imagem: 363 na célula 1357
# Coordenadas inválidas para a imagem: 363 na célula 1358
# Coordenadas inválidas para a imagem: 362 na célula 1376
# Coordenadas inválidas para a imagem: 362 na célula 1377
# Coordenadas inválidas para a imagem: 361 na célula 1456
# Coordenadas inválidas para a imagem: 361 na célula 1457
# Coordenadas inválidas para a imagem: 361 na célula 1476
# Coordenadas inválidas para a imagem: 360 na célula 1490
# Coordenadas inválidas para a imagem: 360 na célula 1503
# Coordenadas inválidas para a imagem: 360 na célula 1521
# Coordenadas inválidas para a imagem: 359 na célula 1530
# Coordenadas inválidas para a imagem: 359 na célula 1542
# Coordenadas inválidas para a imagem: 358 na célula 1550
# Coordenadas inválidas para a imagem: 358 na célula 1551
# Coordenadas inválidas para a imagem: 358 na célula 1560
# Coordenadas inválidas para a imagem: 356 na célula 1586
# Coordenadas inválidas para a imagem: 356 na célula 1589
# Coordenadas inválidas para a imagem: 354 na célula 1629
# Coordenadas inválidas para a imagem: 353 na célula 1633
# Coordenadas inválidas para a imagem: 352 na célula 1641
# Coordenadas inválidas para a imagem: 352 na célula 1642
# Coordenadas inválidas para a imagem: 352 na célula 1654
# Coordenadas inválidas para a imagem: 351 na célula 1673
# Coordenadas inválidas para a imagem: 350 na célula 1694
# Coordenadas inválidas para a imagem: 350 na célula 1707
# Coordenadas inválidas para a imagem: 350 na célula 1709
# Coordenadas inválidas para a imagem: 350 na célula 1730
# Coordenadas inválidas para a imagem: 349 na célula 1735
# Coordenadas inválidas para a imagem: 349 na célula 1754
# Coordenadas inválidas para a imagem: 348 na célula 1780
# Coordenadas inválidas para a imagem: 348 na célula 1783
# Coordenadas inválidas para a imagem: 348 na célula 1784
# Coordenadas inválidas para a imagem: 348 na célula 1794
# Coordenadas inválidas para a imagem: 348 na célula 1801
# Coordenadas inválidas para a imagem: 347 na célula 1820
# Coordenadas inválidas para a imagem: 346 na célula 1830
# Coordenadas inválidas para a imagem: 343 na célula 1865
# Coordenadas inválidas para a imagem: 342 na célula 1890
# Coordenadas inválidas para a imagem: 340 na célula 1943
# Coordenadas inválidas para a imagem: 339 na célula 2028
# Coordenadas inválidas para a imagem: 339 na célula 2029
# Coordenadas inválidas para a imagem: 339 na célula 2030
# Coordenadas inválidas para a imagem: 339 na célula 2046
# Coordenadas inválidas para a imagem: 339 na célula 2056
# Coordenadas inválidas para a imagem: 339 na célula 2067
# Coordenadas inválidas para a imagem: 339 na célula 2070
# Coordenadas inválidas para a imagem: 339 na célula 2088
# Coordenadas inválidas para a imagem: 338 na célula 2121
# Coordenadas inválidas para a imagem: 338 na célula 2148
# Coordenadas inválidas para a imagem: 338 na célula 2149
# Coordenadas inválidas para a imagem: 337 na célula 2177
# Coordenadas inválidas para a imagem: 330 na célula 2338
# Coordenadas inválidas para a imagem: 329 na célula 2355
# Coordenadas inválidas para a imagem: 328 na célula 2363
# Coordenadas inválidas para a imagem: 328 na célula 2367
# Coordenadas inválidas para a imagem: 328 na célula 2373
# Coordenadas inválidas para a imagem: 328 na célula 2383
# Coordenadas inválidas para a imagem: 328 na célula 2386
# Coordenadas inválidas para a imagem: 328 na célula 2389
# Coordenadas inválidas para a imagem: 324 na célula 2424
# Coordenadas inválidas para a imagem: 322 na célula 2452
# Coordenadas inválidas para a imagem: 321 na célula 2467
# Coordenadas inválidas para a imagem: 321 na célula 2477
# Coordenadas inválidas para a imagem: 320 na célula 2485
# Coordenadas inválidas para a imagem: 320 na célula 2491
# Coordenadas inválidas para a imagem: 319 na célula 2499
# Coordenadas inválidas para a imagem: 319 na célula 2501
# Coordenadas inválidas para a imagem: 319 na célula 2505
# Coordenadas inválidas para a imagem: 316 na célula 2532
# Coordenadas inválidas para a imagem: 316 na célula 2533
# Coordenadas inválidas para a imagem: 316 na célula 2534
# Coordenadas inválidas para a imagem: 316 na célula 2536
# Coordenadas inválidas para a imagem: 315 na célula 2554
# Coordenadas inválidas para a imagem: 311 na célula 2636
# Coordenadas inválidas para a imagem: 310 na célula 2714
# Coordenadas inválidas para a imagem: 309 na célula 2731
# Coordenadas inválidas para a imagem: 309 na célula 2732
# Coordenadas inválidas para a imagem: 308 na célula 2752
# Coordenadas inválidas para a imagem: 306 na célula 2786
# Coordenadas inválidas para a imagem: 303 na célula 2849
# Coordenadas inválidas para a imagem: 303 na célula 2854
# Coordenadas inválidas para a imagem: 303 na célula 2856
# Coordenadas inválidas para a imagem: 296 na célula 2911
# Coordenadas inválidas para a imagem: 296 na célula 2916
# Coordenadas inválidas para a imagem: 296 na célula 2917
# Coordenadas inválidas para a imagem: 296 na célula 2918
# Coordenadas inválidas para a imagem: 293 na célula 2968
# Coordenadas inválidas para a imagem: 293 na célula 2980
# Coordenadas inválidas para a imagem: 292 na célula 2988
# Coordenadas inválidas para a imagem: 292 na célula 2989
# Coordenadas inválidas para a imagem: 291 na célula 3013
# Coordenadas inválidas para a imagem: 291 na célula 3015
# Coordenadas inválidas para a imagem: 291 na célula 3016
# Coordenadas inválidas para a imagem: 289 na célula 3042
# Coordenadas inválidas para a imagem: 288 na célula 3069
# Coordenadas inválidas para a imagem: 284 na célula 3126
# Coordenadas inválidas para a imagem: 281 na célula 3184
# Coordenadas inválidas para a imagem: 278 na célula 3253
# Coordenadas inválidas para a imagem: 278 na célula 3256
# Coordenadas inválidas para a imagem: 277 na célula 3295
# Coordenadas inválidas para a imagem: 277 na célula 3335
# Coordenadas inválidas para a imagem: 276 na célula 3342
# Coordenadas inválidas para a imagem: 276 na célula 3353
# Coordenadas inválidas para a imagem: 276 na célula 3354
# Coordenadas inválidas para a imagem: 276 na célula 3362
# Coordenadas inválidas para a imagem: 276 na célula 3363
# Coordenadas inválidas para a imagem: 276 na célula 3372
# Coordenadas inválidas para a imagem: 276 na célula 3373
# Coordenadas inválidas para a imagem: 275 na célula 3398
# Coordenadas inválidas para a imagem: 275 na célula 3399
# Coordenadas inválidas para a imagem: 275 na célula 3400
# Coordenadas inválidas para a imagem: 275 na célula 3407
# Coordenadas inválidas para a imagem: 275 na célula 3415
# Coordenadas inválidas para a imagem: 275 na célula 3417
# Coordenadas inválidas para a imagem: 268 na célula 3550
# Coordenadas inválidas para a imagem: 268 na célula 3552
# Coordenadas inválidas para a imagem: 267 na célula 3561
# Coordenadas inválidas para a imagem: 267 na célula 3562
# Coordenadas inválidas para a imagem: 267 na célula 3564
# Coordenadas inválidas para a imagem: 265 na célula 3612
# Coordenadas inválidas para a imagem: 265 na célula 3634
# Coordenadas inválidas para a imagem: 265 na célula 3637
# Coordenadas inválidas para a imagem: 264 na célula 3659
# Coordenadas inválidas para a imagem: 264 na célula 3660
# Coordenadas inválidas para a imagem: 264 na célula 3662
# Coordenadas inválidas para a imagem: 264 na célula 3663
# Coordenadas inválidas para a imagem: 263 na célula 3672
# Coordenadas inválidas para a imagem: 262 na célula 3681
# Coordenadas inválidas para a imagem: 262 na célula 3689
# Coordenadas inválidas para a imagem: 260 na célula 3711
# Coordenadas inválidas para a imagem: 260 na célula 3720
# Coordenadas inválidas para a imagem: 258 na célula 3759
# Coordenadas inválidas para a imagem: 258 na célula 3760
# Coordenadas inválidas para a imagem: 256 na célula 3801
# Coordenadas inválidas para a imagem: 255 na célula 3814
# Coordenadas inválidas para a imagem: 255 na célula 3839
# Coordenadas inválidas para a imagem: 255 na célula 3840
# Coordenadas inválidas para a imagem: 255 na célula 3841
# Coordenadas inválidas para a imagem: 255 na célula 3842
# Coordenadas inválidas para a imagem: 255 na célula 3843
# Coordenadas inválidas para a imagem: 253 na célula 3864
# Coordenadas inválidas para a imagem: 253 na célula 3865
# Coordenadas inválidas para a imagem: 252 na célula 3884
# Coordenadas inválidas para a imagem: 252 na célula 3911
# Coordenadas inválidas para a imagem: 252 na célula 3912
# Coordenadas inválidas para a imagem: 252 na célula 3913
# Coordenadas inválidas para a imagem: 252 na célula 3914
# Coordenadas inválidas para a imagem: 251 na célula 3925
# Coordenadas inválidas para a imagem: 251 na célula 3935
# Coordenadas inválidas para a imagem: 250 na célula 3972
# Coordenadas inválidas para a imagem: 250 na célula 3973
# Coordenadas inválidas para a imagem: 250 na célula 3975
# Coordenadas inválidas para a imagem: 249 na célula 3985
# Coordenadas inválidas para a imagem: 249 na célula 4011
# Coordenadas inválidas para a imagem: 249 na célula 4012
# Coordenadas inválidas para a imagem: 249 na célula 4013
# Coordenadas inválidas para a imagem: 246 na célula 4098
# Coordenadas inválidas para a imagem: 246 na célula 4099
# Coordenadas inválidas para a imagem: 245 na célula 4127
# Coordenadas inválidas para a imagem: 242 na célula 4196
# Coordenadas inválidas para a imagem: 240 na célula 4244
# Coordenadas inválidas para a imagem: 240 na célula 4245
# Coordenadas inválidas para a imagem: 238 na célula 4269
# Coordenadas inválidas para a imagem: 236 na célula 4344
# Coordenadas inválidas para a imagem: 236 na célula 4345
# Coordenadas inválidas para a imagem: 236 na célula 4346
# Coordenadas inválidas para a imagem: 236 na célula 4347
# Coordenadas inválidas para a imagem: 236 na célula 4348
# Coordenadas inválidas para a imagem: 236 na célula 4349
# Coordenadas inválidas para a imagem: 236 na célula 4352
# Coordenadas inválidas para a imagem: 236 na célula 4353
# Coordenadas inválidas para a imagem: 236 na célula 4355
# Coordenadas inválidas para a imagem: 235 na célula 4384
# Coordenadas inválidas para a imagem: 235 na célula 4385
# Coordenadas inválidas para a imagem: 235 na célula 4397
# Coordenadas inválidas para a imagem: 235 na célula 4398
# Coordenadas inválidas para a imagem: 234 na célula 4452
# Coordenadas inválidas para a imagem: 234 na célula 4453
# Coordenadas inválidas para a imagem: 233 na célula 4470
# Coordenadas inválidas para a imagem: 232 na célula 4481
# Coordenadas inválidas para a imagem: 228 na célula 4618
# Coordenadas inválidas para a imagem: 228 na célula 4619
# Coordenadas inválidas para a imagem: 225 na célula 4652
# Coordenadas inválidas para a imagem: 225 na célula 4656
# Coordenadas inválidas para a imagem: 224 na célula 4683
# Coordenadas inválidas para a imagem: 224 na célula 4693
# Coordenadas inválidas para a imagem: 224 na célula 4694
# Coordenadas inválidas para a imagem: 223 na célula 4705
# Coordenadas inválidas para a imagem: 222 na célula 4719
# Coordenadas inválidas para a imagem: 222 na célula 4720
# Coordenadas inválidas para a imagem: 221 na célula 4746
# Coordenadas inválidas para a imagem: 221 na célula 4747
# Coordenadas inválidas para a imagem: 220 na célula 4767
# Coordenadas inválidas para a imagem: 220 na célula 4780
# Coordenadas inválidas para a imagem: 218 na célula 4800
# Coordenadas inválidas para a imagem: 218 na célula 4802
# Coordenadas inválidas para a imagem: 217 na célula 4821
# Coordenadas inválidas para a imagem: 217 na célula 4823
# Coordenadas inválidas para a imagem: 217 na célula 4824
# Coordenadas inválidas para a imagem: 216 na célula 4845
# Coordenadas inválidas para a imagem: 216 na célula 4846
# Coordenadas inválidas para a imagem: 215 na célula 4849
# Coordenadas inválidas para a imagem: 215 na célula 4857
# Coordenadas inválidas para a imagem: 214 na célula 4871
# Coordenadas inválidas para a imagem: 212 na célula 4898
# Coordenadas inválidas para a imagem: 213 na célula 4913
# Coordenadas inválidas para a imagem: 208 na célula 4955
# Coordenadas inválidas para a imagem: 208 na célula 4974
# Coordenadas inválidas para a imagem: 208 na célula 4975
# Coordenadas inválidas para a imagem: 206 na célula 4986
# Coordenadas inválidas para a imagem: 206 na célula 5000
# Coordenadas inválidas para a imagem: 205 na célula 5016
# Coordenadas inválidas para a imagem: 205 na célula 5017
# Coordenadas inválidas para a imagem: 205 na célula 5018
# Coordenadas inválidas para a imagem: 205 na célula 5022
# Coordenadas inválidas para a imagem: 205 na célula 5031
# Coordenadas inválidas para a imagem: 199 na célula 5078
# Coordenadas inválidas para a imagem: 195 na célula 5123
# Coordenadas inválidas para a imagem: 192 na célula 5165
# Coordenadas inválidas para a imagem: 190 na célula 5208
# Coordenadas inválidas para a imagem: 186 na célula 5283
# Coordenadas inválidas para a imagem: 186 na célula 5284
# Coordenadas inválidas para a imagem: 185 na célula 5307
# Coordenadas inválidas para a imagem: 184 na célula 5324
# Coordenadas inválidas para a imagem: 184 na célula 5327
# Coordenadas inválidas para a imagem: 182 na célula 5335
# Coordenadas inválidas para a imagem: 182 na célula 5336
# Coordenadas inválidas para a imagem: 182 na célula 5337
# Coordenadas inválidas para a imagem: 183 na célula 5368
# Coordenadas inválidas para a imagem: 183 na célula 5372
# Coordenadas inválidas para a imagem: 181 na célula 5398
# Coordenadas inválidas para a imagem: 180 na célula 5420
# Coordenadas inválidas para a imagem: 176 na célula 5441
# Coordenadas inválidas para a imagem: 177 na célula 5451
# Coordenadas inválidas para a imagem: 177 na célula 5452
# Coordenadas inválidas para a imagem: 177 na célula 5454
# Coordenadas inválidas para a imagem: 173 na célula 5525
# Coordenadas inválidas para a imagem: 173 na célula 5526
# Coordenadas inválidas para a imagem: 171 na célula 5557
# Coordenadas inválidas para a imagem: 163 na célula 5626
# Coordenadas inválidas para a imagem: 162 na célula 5649
# Coordenadas inválidas para a imagem: 162 na célula 5651
# Coordenadas inválidas para a imagem: 160 na célula 5687
# Coordenadas inválidas para a imagem: 160 na célula 5693
# Coordenadas inválidas para a imagem: 160 na célula 5694
# Coordenadas inválidas para a imagem: 159 na célula 5708
# Coordenadas inválidas para a imagem: 157 na célula 5732
# Coordenadas inválidas para a imagem: 157 na célula 5733
# Coordenadas inválidas para a imagem: 157 na célula 5734
# Coordenadas inválidas para a imagem: 157 na célula 5735
# Coordenadas inválidas para a imagem: 157 na célula 5741
# Coordenadas inválidas para a imagem: 157 na célula 5742
# Coordenadas inválidas para a imagem: 155 na célula 5781
# Coordenadas inválidas para a imagem: 155 na célula 5783
# Coordenadas inválidas para a imagem: 155 na célula 5784
# Coordenadas inválidas para a imagem: 155 na célula 5800
# Coordenadas inválidas para a imagem: 155 na célula 5804
# Coordenadas inválidas para a imagem: 155 na célula 5806
# Coordenadas inválidas para a imagem: 155 na célula 5807
# Coordenadas inválidas para a imagem: 154 na célula 5827
# Coordenadas inválidas para a imagem: 151 na célula 5886
# Coordenadas inválidas para a imagem: 152 na célula 5932
# Coordenadas inválidas para a imagem: 152 na célula 5935
# Coordenadas inválidas para a imagem: 149 na célula 5937
# Coordenadas inválidas para a imagem: 149 na célula 5939
# Coordenadas inválidas para a imagem: 149 na célula 5943
# Coordenadas inválidas para a imagem: 149 na célula 5961
# Coordenadas inválidas para a imagem: 149 na célula 5962
# Coordenadas inválidas para a imagem: 150 na célula 6004
# Coordenadas inválidas para a imagem: 148 na célula 6008
# Coordenadas inválidas para a imagem: 148 na célula 6009
# Coordenadas inválidas para a imagem: 148 na célula 6010
# Coordenadas inválidas para a imagem: 148 na célula 6050
# Coordenadas inválidas para a imagem: 148 na célula 6056
# Coordenadas inválidas para a imagem: 148 na célula 6058
# Coordenadas inválidas para a imagem: 148 na célula 6059
# Coordenadas inválidas para a imagem: 148 na célula 6065
# Coordenadas inválidas para a imagem: 147 na célula 6086
# Coordenadas inválidas para a imagem: 147 na célula 6112
# Coordenadas inválidas para a imagem: 147 na célula 6113
# Coordenadas inválidas para a imagem: 147 na célula 6128
# Coordenadas inválidas para a imagem: 146 na célula 6132
# Coordenadas inválidas para a imagem: 146 na célula 6133
# Coordenadas inválidas para a imagem: 146 na célula 6139
# Coordenadas inválidas para a imagem: 146 na célula 6154
# Coordenadas inválidas para a imagem: 146 na célula 6157
# Coordenadas inválidas para a imagem: 146 na célula 6159
# Coordenadas inválidas para a imagem: 146 na célula 6160
# Coordenadas inválidas para a imagem: 144 na célula 6162
# Coordenadas inválidas para a imagem: 144 na célula 6163
# Coordenadas inválidas para a imagem: 144 na célula 6164
# Coordenadas inválidas para a imagem: 144 na célula 6172
# Coordenadas inválidas para a imagem: 144 na célula 6174
# Coordenadas inválidas para a imagem: 144 na célula 6175
# Coordenadas inválidas para a imagem: 144 na célula 6195
# Coordenadas inválidas para a imagem: 144 na célula 6197
# Coordenadas inválidas para a imagem: 145 na célula 6208
# Coordenadas inválidas para a imagem: 145 na célula 6225
# Coordenadas inválidas para a imagem: 143 na célula 6227
# Coordenadas inválidas para a imagem: 143 na célula 6228
# Coordenadas inválidas para a imagem: 143 na célula 6230
# Coordenadas inválidas para a imagem: 143 na célula 6234
# Coordenadas inválidas para a imagem: 143 na célula 6235
# Coordenadas inválidas para a imagem: 143 na célula 6243
# Coordenadas inválidas para a imagem: 143 na célula 6255
# Coordenadas inválidas para a imagem: 142 na célula 6256
# Coordenadas inválidas para a imagem: 142 na célula 6257
# Coordenadas inválidas para a imagem: 142 na célula 6258
# Coordenadas inválidas para a imagem: 142 na célula 6281
# Coordenadas inválidas para a imagem: 141 na célula 6282
# Coordenadas inválidas para a imagem: 141 na célula 6284
# Coordenadas inválidas para a imagem: 141 na célula 6288
# Coordenadas inválidas para a imagem: 141 na célula 6307
# Coordenadas inválidas para a imagem: 141 na célula 6323
# Coordenadas inválidas para a imagem: 140 na célula 6326
# Coordenadas inválidas para a imagem: 140 na célula 6337
# Coordenadas inválidas para a imagem: 140 na célula 6349
# Coordenadas inválidas para a imagem: 140 na célula 6357
# Coordenadas inválidas para a imagem: 140 na célula 6371
# Coordenadas inválidas para a imagem: 140 na célula 6377
# Coordenadas inválidas para a imagem: 140 na célula 6380
# Coordenadas inválidas para a imagem: 140 na célula 6381
# Coordenadas inválidas para a imagem: 138 na célula 6385
# Coordenadas inválidas para a imagem: 138 na célula 6386
# Coordenadas inválidas para a imagem: 138 na célula 6389
# Coordenadas inválidas para a imagem: 138 na célula 6419
# Coordenadas inválidas para a imagem: 138 na célula 6423
# Coordenadas inválidas para a imagem: 139 na célula 6428
# Coordenadas inválidas para a imagem: 139 na célula 6434
# Coordenadas inválidas para a imagem: 136 na célula 6444
# Coordenadas inválidas para a imagem: 136 na célula 6446
# Coordenadas inválidas para a imagem: 136 na célula 6471
# Coordenadas inválidas para a imagem: 136 na célula 6472
# Coordenadas inválidas para a imagem: 136 na célula 6477
# Coordenadas inválidas para a imagem: 137 na célula 6482
# Coordenadas inválidas para a imagem: 137 na célula 6483
# Coordenadas inválidas para a imagem: 137 na célula 6524
# Coordenadas inválidas para a imagem: 137 na célula 6525
# Coordenadas inválidas para a imagem: 135 na célula 6536
# Coordenadas inválidas para a imagem: 135 na célula 6542
# Coordenadas inválidas para a imagem: 135 na célula 6553
# Coordenadas inválidas para a imagem: 135 na célula 6555
# Coordenadas inválidas para a imagem: 135 na célula 6556
# Coordenadas inválidas para a imagem: 135 na célula 6571
# Coordenadas inválidas para a imagem: 135 na célula 6580
# Coordenadas inválidas para a imagem: 135 na célula 6581
# Coordenadas inválidas para a imagem: 134 na célula 6584
# Coordenadas inválidas para a imagem: 134 na célula 6590
# Coordenadas inválidas para a imagem: 134 na célula 6602
# Coordenadas inválidas para a imagem: 134 na célula 6603
# Coordenadas inválidas para a imagem: 133 na célula 6621
# Coordenadas inválidas para a imagem: 133 na célula 6624
# Coordenadas inválidas para a imagem: 133 na célula 6634
# Coordenadas inválidas para a imagem: 133 na célula 6646
# Coordenadas inválidas para a imagem: 131 na célula 6662
# Coordenadas inválidas para a imagem: 132 na célula 6664
# Coordenadas inválidas para a imagem: 132 na célula 6665
# Coordenadas inválidas para a imagem: 132 na célula 6674
# Coordenadas inválidas para a imagem: 132 na célula 6675
# Coordenadas inválidas para a imagem: 132 na célula 6678
# Coordenadas inválidas para a imagem: 132 na célula 6679
# Coordenadas inválidas para a imagem: 132 na célula 6680
# Coordenadas inválidas para a imagem: 132 na célula 6681
# Coordenadas inválidas para a imagem: 132 na célula 6690
# Coordenadas inválidas para a imagem: 132 na célula 6692
# Coordenadas inválidas para a imagem: 132 na célula 6708
# Coordenadas inválidas para a imagem: 132 na célula 6715
# Coordenadas inválidas para a imagem: 132 na célula 6716
# Coordenadas inválidas para a imagem: 132 na célula 6717
# Coordenadas inválidas para a imagem: 132 na célula 6719
# Coordenadas inválidas para a imagem: 132 na célula 6720
# Coordenadas inválidas para a imagem: 132 na célula 6721
# Coordenadas inválidas para a imagem: 129 na célula 6724
# Coordenadas inválidas para a imagem: 129 na célula 6725
# Coordenadas inválidas para a imagem: 129 na célula 6766
# Coordenadas inválidas para a imagem: 130 na célula 6778
# Coordenadas inválidas para a imagem: 130 na célula 6781
# Coordenadas inválidas para a imagem: 130 na célula 6783
# Coordenadas inválidas para a imagem: 130 na célula 6787
# Coordenadas inválidas para a imagem: 130 na célula 6797
# Coordenadas inválidas para a imagem: 130 na célula 6798
# Coordenadas inválidas para a imagem: 130 na célula 6823
# Coordenadas inválidas para a imagem: 126 na célula 6870
# Coordenadas inválidas para a imagem: 127 na célula 6896
# Coordenadas inválidas para a imagem: 125 na célula 6940
# Coordenadas inválidas para a imagem: 125 na célula 6944
# Coordenadas inválidas para a imagem: 125 na célula 6945
# Coordenadas inválidas para a imagem: 125 na célula 6946
# Coordenadas inválidas para a imagem: 125 na célula 6947
# Coordenadas inválidas para a imagem: 125 na célula 6948
# Coordenadas inválidas para a imagem: 125 na célula 6952
# Coordenadas inválidas para a imagem: 123 na célula 6979
# Coordenadas inválidas para a imagem: 123 na célula 6980
# Coordenadas inválidas para a imagem: 124 na célula 7020
# Coordenadas inválidas para a imagem: 124 na célula 7021
# Coordenadas inválidas para a imagem: 124 na célula 7022
# Coordenadas inválidas para a imagem: 124 na célula 7024
# Coordenadas inválidas para a imagem: 124 na célula 7025
# Coordenadas inválidas para a imagem: 121 na célula 7034
# Coordenadas inválidas para a imagem: 121 na célula 7047
# Coordenadas inválidas para a imagem: 121 na célula 7060
# Coordenadas inválidas para a imagem: 121 na célula 7061
# Coordenadas inválidas para a imagem: 121 na célula 7062
# Coordenadas inválidas para a imagem: 121 na célula 7063
# Coordenadas inválidas para a imagem: 120 na célula 7133
# Coordenadas inválidas para a imagem: 117 na célula 7183
# Coordenadas inválidas para a imagem: 118 na célula 7215
# Coordenadas inválidas para a imagem: 118 na célula 7218
# Coordenadas inválidas para a imagem: 118 na célula 7219
# Coordenadas inválidas para a imagem: 115 na célula 7240
# Coordenadas inválidas para a imagem: 115 na célula 7241
# Coordenadas inválidas para a imagem: 115 na célula 7242
# Coordenadas inválidas para a imagem: 116 na célula 7293
# Coordenadas inválidas para a imagem: 116 na célula 7294
# Coordenadas inválidas para a imagem: 116 na célula 7297
# Coordenadas inválidas para a imagem: 116 na célula 7298
# Coordenadas inválidas para a imagem: 114 na célula 7336
# Coordenadas inválidas para a imagem: 114 na célula 7337
# Coordenadas inválidas para a imagem: 114 na célula 7338
# Coordenadas inválidas para a imagem: 114 na célula 7339
# Coordenadas inválidas para a imagem: 112 na célula 7342
# Coordenadas inválidas para a imagem: 112 na célula 7381
# Coordenadas inválidas para a imagem: 112 na célula 7382
# Coordenadas inválidas para a imagem: 112 na célula 7383
# Coordenadas inválidas para a imagem: 111 na célula 7436
# Coordenadas inválidas para a imagem: 111 na célula 7440
# Coordenadas inválidas para a imagem: 111 na célula 7441
# Coordenadas inválidas para a imagem: 110 na célula 7458
# Coordenadas inválidas para a imagem: 109 na célula 7485
# Coordenadas inválidas para a imagem: 109 na célula 7496
# Coordenadas inválidas para a imagem: 109 na célula 7497
# Coordenadas inválidas para a imagem: 109 na célula 7498
# Coordenadas inválidas para a imagem: 109 na célula 7499
# Coordenadas inválidas para a imagem: 108 na célula 7545
# Coordenadas inválidas para a imagem: 108 na célula 7546
# Coordenadas inválidas para a imagem: 108 na célula 7547
# Coordenadas inválidas para a imagem: 104 na célula 7566
# Coordenadas inválidas para a imagem: 103 na célula 7578
# Coordenadas inválidas para a imagem: 102 na célula 7596
# Coordenadas inválidas para a imagem: 100 na célula 7644
# Coordenadas inválidas para a imagem: 97 na célula 7682
# Coordenadas inválidas para a imagem: 97 na célula 7683
# Coordenadas inválidas para a imagem: 97 na célula 7685
# Coordenadas inválidas para a imagem: 98 na célula 7691
# Coordenadas inválidas para a imagem: 96 na célula 7713
# Coordenadas inválidas para a imagem: 96 na célula 7715
# Coordenadas inválidas para a imagem: 94 na célula 7726
# Coordenadas inválidas para a imagem: 93 na célula 7787
# Coordenadas inválidas para a imagem: 93 na célula 7788
# Coordenadas inválidas para a imagem: 93 na célula 7789
# Coordenadas inválidas para a imagem: 93 na célula 7792
# Coordenadas inválidas para a imagem: 91 na célula 7873
# Coordenadas inválidas para a imagem: 91 na célula 7878
# Coordenadas inválidas para a imagem: 88 na célula 7950
# Coordenadas inválidas para a imagem: 87 na célula 7978
# Coordenadas inválidas para a imagem: 86 na célula 8007
# Coordenadas inválidas para a imagem: 86 na célula 8008
# Coordenadas inválidas para a imagem: 84 na célula 8033
# Coordenadas inválidas para a imagem: 85 na célula 8101
# Coordenadas inválidas para a imagem: 85 na célula 8115
# Coordenadas inválidas para a imagem: 85 na célula 8116
# Coordenadas inválidas para a imagem: 78 na célula 8268
# Coordenadas inválidas para a imagem: 76 na célula 8350
# Coordenadas inválidas para a imagem: 75 na célula 8490
# Coordenadas inválidas para a imagem: 75 na célula 8496
# Coordenadas inválidas para a imagem: 71 na célula 8745
# Coordenadas inválidas para a imagem: 71 na célula 8747
# Coordenadas inválidas para a imagem: 69 na célula 8784
# Coordenadas inválidas para a imagem: 69 na célula 8785
# Coordenadas inválidas para a imagem: 69 na célula 8790
# Coordenadas inválidas para a imagem: 69 na célula 8791
# Coordenadas inválidas para a imagem: 70 na célula 8861
# Coordenadas inválidas para a imagem: 70 na célula 8866
# Coordenadas inválidas para a imagem: 70 na célula 8881
# Coordenadas inválidas para a imagem: 67 na célula 8919
# Coordenadas inválidas para a imagem: 68 na célula 9009
# Coordenadas inválidas para a imagem: 66 na célula 9064
# Coordenadas inválidas para a imagem: 64 na célula 9177
# Coordenadas inválidas para a imagem: 64 na célula 9179
# Coordenadas inválidas para a imagem: 62 na célula 9411
# Coordenadas inválidas para a imagem: 58 na célula 9553
# Coordenadas inválidas para a imagem: 58 na célula 9560
# Coordenadas inválidas para a imagem: 58 na célula 9569
# Coordenadas inválidas para a imagem: 58 na célula 9571
# Coordenadas inválidas para a imagem: 59 na célula 9601
# Coordenadas inválidas para a imagem: 52 na célula 9824
# Coordenadas inválidas para a imagem: 51 na célula 9908
# Coordenadas inválidas para a imagem: 51 na célula 9910
# Coordenadas inválidas para a imagem: 51 na célula 9911
# Coordenadas inválidas para a imagem: 50 na célula 9945
# Coordenadas inválidas para a imagem: 49 na célula 9960
# Coordenadas inválidas para a imagem: 49 na célula 9963
# Coordenadas inválidas para a imagem: 49 na célula 9968
# Coordenadas inválidas para a imagem: 45 na célula 10048
# Coordenadas inválidas para a imagem: 45 na célula 10050
# Coordenadas inválidas para a imagem: 45 na célula 10055
# Coordenadas inválidas para a imagem: 44 na célula 10108
# Coordenadas inválidas para a imagem: 44 na célula 10118
# Coordenadas inválidas para a imagem: 44 na célula 10132
# Coordenadas inválidas para a imagem: 42 na célula 10148
# Coordenadas inválidas para a imagem: 41 na célula 10171
# Coordenadas inválidas para a imagem: 39 na célula 10190
# Coordenadas inválidas para a imagem: 39 na célula 10191
# Coordenadas inválidas para a imagem: 39 na célula 10208
# Coordenadas inválidas para a imagem: 39 na célula 10216
# Coordenadas inválidas para a imagem: 39 na célula 10217
# Coordenadas inválidas para a imagem: 38 na célula 10279
# Coordenadas inválidas para a imagem: 38 na célula 10280
# Coordenadas inválidas para a imagem: 38 na célula 10281
# Coordenadas inválidas para a imagem: 38 na célula 10282
# Coordenadas inválidas para a imagem: 38 na célula 10284
# Coordenadas inválidas para a imagem: 38 na célula 10310
# Coordenadas inválidas para a imagem: 35 na célula 10349
# Coordenadas inválidas para a imagem: 36 na célula 10353
# Coordenadas inválidas para a imagem: 36 na célula 10365
# Coordenadas inválidas para a imagem: 32 na célula 10388
# Coordenadas inválidas para a imagem: 33 na célula 10392
# Coordenadas inválidas para a imagem: 33 na célula 10394
# Coordenadas inválidas para a imagem: 33 na célula 10396
# Coordenadas inválidas para a imagem: 33 na célula 10433
# Coordenadas inválidas para a imagem: 31 na célula 10439
# Coordenadas inválidas para a imagem: 31 na célula 10440
# Coordenadas inválidas para a imagem: 31 na célula 10442
# Coordenadas inválidas para a imagem: 31 na célula 10497
# Coordenadas inválidas para a imagem: 31 na célula 10498
# Coordenadas inválidas para a imagem: 31 na célula 10502
# Coordenadas inválidas para a imagem: 31 na célula 10505
# Coordenadas inválidas para a imagem: 30 na célula 10512
# Coordenadas inválidas para a imagem: 29 na célula 10559
# Coordenadas inválidas para a imagem: 29 na célula 10560
# Coordenadas inválidas para a imagem: 29 na célula 10601
# Coordenadas inválidas para a imagem: 29 na célula 10602
# Coordenadas inválidas para a imagem: 29 na célula 10603
# Coordenadas inválidas para a imagem: 29 na célula 10604
# Coordenadas inválidas para a imagem: 29 na célula 10605
# Coordenadas inválidas para a imagem: 28 na célula 10607
# Coordenadas inválidas para a imagem: 28 na célula 10636
# Coordenadas inválidas para a imagem: 28 na célula 10637
# Coordenadas inválidas para a imagem: 26 na célula 10656
# Coordenadas inválidas para a imagem: 26 na célula 10709
# Coordenadas inválidas para a imagem: 26 na célula 10710
# Coordenadas inválidas para a imagem: 26 na célula 10711
# Coordenadas inválidas para a imagem: 27 na célula 10748
# Coordenadas inválidas para a imagem: 27 na célula 10749
# Coordenadas inválidas para a imagem: 27 na célula 10751
# Coordenadas inválidas para a imagem: 24 na célula 10771
# Coordenadas inválidas para a imagem: 25 na célula 10821
# Coordenadas inválidas para a imagem: 25 na célula 10822
# Coordenadas inválidas para a imagem: 25 na célula 10823
# Coordenadas inválidas para a imagem: 25 na célula 10824
# Coordenadas inválidas para a imagem: 25 na célula 10825
# Coordenadas inválidas para a imagem: 22 na célula 10868
# Coordenadas inválidas para a imagem: 22 na célula 10869
# Coordenadas inválidas para a imagem: 22 na célula 10870
# Coordenadas inválidas para a imagem: 22 na célula 10871
# Coordenadas inválidas para a imagem: 22 na célula 10872
# Coordenadas inválidas para a imagem: 22 na célula 10873
# Coordenadas inválidas para a imagem: 22 na célula 10877
# Coordenadas inválidas para a imagem: 23 na célula 10923
# Coordenadas inválidas para a imagem: 21 na célula 10945
# Coordenadas inválidas para a imagem: 19 na célula 10977
# Coordenadas inválidas para a imagem: 19 na célula 10978
# Coordenadas inválidas para a imagem: 19 na célula 10979
# Coordenadas inválidas para a imagem: 18 na célula 11030
# Coordenadas inválidas para a imagem: 18 na célula 11031
# Coordenadas inválidas para a imagem: 18 na célula 11032
# Coordenadas inválidas para a imagem: 18 na célula 11033
# Coordenadas inválidas para a imagem: 18 na célula 11034
# Coordenadas inválidas para a imagem: 18 na célula 11035
# Coordenadas inválidas para a imagem: 18 na célula 11036
# Coordenadas inválidas para a imagem: 18 na célula 11037
# Coordenadas inválidas para a imagem: 18 na célula 11038
# Coordenadas inválidas para a imagem: 18 na célula 11039
# Coordenadas inválidas para a imagem: 18 na célula 11040
# Coordenadas inválidas para a imagem: 16 na célula 11076
# Coordenadas inválidas para a imagem: 16 na célula 11078
# Coordenadas inválidas para a imagem: 16 na célula 11079
# Coordenadas inválidas para a imagem: 17 na célula 11097
# Coordenadas inválidas para a imagem: 17 na célula 11111
# Coordenadas inválidas para a imagem: 17 na célula 11112
# Coordenadas inválidas para a imagem: 14 na célula 11138
# Coordenadas inválidas para a imagem: 15 na célula 11172
# Coordenadas inválidas para a imagem: 15 na célula 11173
# Coordenadas inválidas para a imagem: 15 na célula 11174
# Coordenadas inválidas para a imagem: 13 na célula 11215
# Coordenadas inválidas para a imagem: 13 na célula 11216
# Coordenadas inválidas para a imagem: 13 na célula 11217
# Coordenadas inválidas para a imagem: 13 na célula 11225
# Coordenadas inválidas para a imagem: 13 na célula 11230
# Coordenadas inválidas para a imagem: 11 na célula 11263
# Coordenadas inválidas para a imagem: 9 na célula 11302
# Coordenadas inválidas para a imagem: 8 na célula 11338
# Coordenadas inválidas para a imagem: 8 na célula 11339
# Coordenadas inválidas para a imagem: 8 na célula 11340
# Coordenadas inválidas para a imagem: 8 na célula 11342
# Coordenadas inválidas para a imagem: 8 na célula 11343
# Coordenadas inválidas para a imagem: 8 na célula 11344
# Coordenadas inválidas para a imagem: 8 na célula 11349
# Coordenadas inválidas para a imagem: 6 na célula 11360
# Coordenadas inválidas para a imagem: 6 na célula 11361
# Coordenadas inválidas para a imagem: 5 na célula 11427
# Coordenadas inválidas para a imagem: 3 na célula 11461
# Coordenadas inválidas para a imagem: 2 na célula 11479
# Coordenadas inválidas para a imagem: 1 na célula 11493
# Coordenadas inválidas para a imagem: 1 na célula 11495
# Coordenadas inválidas para a imagem: 1 na célula 11497
