# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from skimage.feature import graycomatrix, graycoprops
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import joblib
from sklearn.metrics import classification_report, accuracy_score

def get_haralick_descriptors(image_pil_color):
    # Convert PIL image to NumPy array
    array = np.array(image_pil_color)
    
    # Convert BGR to RGB
    image_rgb = cv2.cvtColor(array, cv2.COLOR_BGR2RGB)
    
    # Convert RGB to grayscale
    image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)
    
    # Reduce image to 16 gray levels
    image_gray //= 16
    
    # Define distances and angle
    distances = [1, 2, 4, 8, 16, 31]
    angle = 0
    
    features = []
    
    # Compute GLCM and Haralick features
    for d in distances:
        glcm = graycomatrix(image_gray, distances=[d], angles=[angle], levels=16, symmetric=True, normed=True)
        contrast = graycoprops(glcm, 'contrast')[0, 0]
        homogeneity = graycoprops(glcm, 'homogeneity')[0, 0]
        entropy = -np.sum(glcm * np.log2(glcm + np.finfo(float).eps))
        
        # Collect the features
        features.extend([contrast, homogeneity, entropy])
    
    return features

# Base directory containing subdirectories of images
base_dir = "sub_images"

# List to hold image data and labels
features = []
labels = []

# Iterate through each subdirectory in the base directory
for subdir in os.listdir(base_dir):
    subdir_path = os.path.join(base_dir, subdir)
    
    # Check if it's a directory
    if os.path.isdir(subdir_path):
        # Process each image in the subdirectory
        for filename in os.listdir(subdir_path):
            if filename.endswith(".png"):
                # Construct full file path
                file_path = os.path.join(subdir_path, filename)
                # Open the image with PIL
                with Image.open(file_path) as img:
                    # Extract Haralick descriptors
                    img_features = get_haralick_descriptors(img)
                    
                    # Append the processed features and label
                    features.append(img_features)
                    if subdir == "Negative for intraepithelial lesion":
                        labels.append("sem_doenca")
                    else:
                        labels.append("com_doenca")

# Convert list to NumPy arrays for machine learning processing
features = np.array(features)
labels = np.array(labels)

# Split data into 80% train and 20% test subsets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.20, random_state=42)

# Optional: scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create the SVM model with balanced class weights
model = svm.SVC(kernel='rbf', gamma='scale', class_weight='balanced')
model.fit(X_train_scaled, y_train)

# Save the model
joblib.dump(model, 'svm_haralick_model_binario.joblib')

# Load the model
loaded_model = joblib.load('svm_haralick_model_binario.joblib')

# Use the loaded model to make predictions
y_pred = loaded_model.predict(X_test_scaled)

# Print classification report
print("Classification report for classifier %s:\n%s\n"
      % (model, classification_report(y_test, y_pred)))
# Out:
# Classification report for classifier SVC(class_weight='balanced'):
#               precision    recall  f1-score   support
#
#   com_doenca       0.66      0.72      0.69       958
#   sem_doenca       0.76      0.71      0.74      1216
#
#     accuracy                           0.72      2174
#    macro avg       0.71      0.72      0.71      2174
# weighted avg       0.72      0.72      0.72      2174

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Define the parameter grid to search
param_grid = {
    'C': [0.1, 1, 10, 100],  # Regularization parameter
    'gamma': ['scale', 0.001, 0.01, 0.1, 1],  # Kernel coefficient for 'rbf'
}

# Create a GridSearchCV object
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy', verbose=3)

# Fit GridSearchCV
grid_search.fit(X_train_scaled, y_train)

# Best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))

# Retrain model with best parameters
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_scaled)

# Evaluate the classifier performance on the test set
print(classification_report(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END ................C=0.1, gamma=scale;, score=0.670 total time=   1.3s
# [CV 2/5] END ................C=0.1, gamma=scale;, score=0.670 total time=   1.3s
# [CV 3/5] END ................C=0.1, gamma=scale;, score=0.676 total time=   1.3s
# [CV 4/5] END ................C=0.1, gamma=scale;, score=0.673 total time=   1.3s
# [CV 5/5] END ................C=0.1, gamma=scale;, score=0.664 total time=   1.3s
# [CV 1/5] END ................C=0.1, gamma=0.001;, score=0.621 total time=   1.6s
# [CV 2/5] END ................C=0.1, gamma=0.001;, score=0.627 total time=   1.6s
# [CV 3/5] END ................C=0.1, gamma=0.001;, score=0.615 total time=   1.6s
# [CV 4/5] END ................C=0.1, gamma=0.001;, score=0.620 total time=   1.6s
# [CV 5/5] END ................C=0.1, gamma=0.001;, score=0.622 total time=   1.6s
# [CV 1/5] END .................C=0.1, gamma=0.01;, score=0.643 total time=   1.4s
# [CV 2/5] END .................C=0.1, gamma=0.01;, score=0.652 total time=   1.4s
# [CV 3/5] END .................C=0.1, gamma=0.01;, score=0.652 total time=   1.4s
# [CV 4/5] END .................C=0.1, gamma=0.01;, score=0.659 total time=   1.4s
# [CV 5/5] END .................C=0.1, gamma=0.01;, score=0.654 total time=   1.4s
# [CV 1/5] END ..................C=0.1, gamma=0.1;, score=0.672 total time=   1.3s
# [CV 2/5] END ..................C=0.1, gamma=0.1;, score=0.672 total time=   1.3s
# [CV 3/5] END ..................C=0.1, gamma=0.1;, score=0.680 total time=   1.3s
# [CV 4/5] END ..................C=0.1, gamma=0.1;, score=0.684 total time=   1.3s
# [CV 5/5] END ..................C=0.1, gamma=0.1;, score=0.664 total time=   1.3s
# [CV 1/5] END ....................C=0.1, gamma=1;, score=0.649 total time=   1.5s
# [CV 2/5] END ....................C=0.1, gamma=1;, score=0.651 total time=   1.5s
# [CV 3/5] END ....................C=0.1, gamma=1;, score=0.641 total time=   1.5s
# [CV 4/5] END ....................C=0.1, gamma=1;, score=0.661 total time=   1.5s
# [CV 5/5] END ....................C=0.1, gamma=1;, score=0.648 total time=   1.5s
# [CV 1/5] END ..................C=1, gamma=scale;, score=0.685 total time=   1.2s
# [CV 2/5] END ..................C=1, gamma=scale;, score=0.708 total time=   1.2s
# [CV 3/5] END ..................C=1, gamma=scale;, score=0.692 total time=   1.2s
# [CV 4/5] END ..................C=1, gamma=scale;, score=0.704 total time=   1.2s
# [CV 5/5] END ..................C=1, gamma=scale;, score=0.707 total time=   1.2s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.637 total time=   1.5s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.647 total time=   1.4s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.649 total time=   1.4s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.657 total time=   1.5s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=0.657 total time=   1.5s
# [CV 1/5] END ...................C=1, gamma=0.01;, score=0.684 total time=   1.3s
# [CV 2/5] END ...................C=1, gamma=0.01;, score=0.695 total time=   1.3s
# [CV 3/5] END ...................C=1, gamma=0.01;, score=0.696 total time=   1.3s
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.695 total time=   1.3s
# [CV 5/5] END ...................C=1, gamma=0.01;, score=0.690 total time=   1.3s
# [CV 1/5] END ....................C=1, gamma=0.1;, score=0.694 total time=   1.2s
# [CV 2/5] END ....................C=1, gamma=0.1;, score=0.701 total time=   1.3s
# [CV 3/5] END ....................C=1, gamma=0.1;, score=0.692 total time=   1.2s
# [CV 4/5] END ....................C=1, gamma=0.1;, score=0.710 total time=   1.2s
# [CV 5/5] END ....................C=1, gamma=0.1;, score=0.710 total time=   1.2s
# [CV 1/5] END ......................C=1, gamma=1;, score=0.687 total time=   1.4s
# [CV 2/5] END ......................C=1, gamma=1;, score=0.682 total time=   1.4s
# [CV 3/5] END ......................C=1, gamma=1;, score=0.688 total time=   1.4s
# [CV 4/5] END ......................C=1, gamma=1;, score=0.702 total time=   1.4s
# [CV 5/5] END ......................C=1, gamma=1;, score=0.686 total time=   1.3s
# [CV 1/5] END .................C=10, gamma=scale;, score=0.714 total time=   1.2s
# [CV 2/5] END .................C=10, gamma=scale;, score=0.717 total time=   1.3s
# [CV 3/5] END .................C=10, gamma=scale;, score=0.715 total time=   1.2s
# [CV 4/5] END .................C=10, gamma=scale;, score=0.721 total time=   1.2s
# [CV 5/5] END .................C=10, gamma=scale;, score=0.728 total time=   1.2s
# [CV 1/5] END .................C=10, gamma=0.001;, score=0.671 total time=   1.3s
# [CV 2/5] END .................C=10, gamma=0.001;, score=0.679 total time=   1.4s
# [CV 3/5] END .................C=10, gamma=0.001;, score=0.679 total time=   1.3s
# [CV 4/5] END .................C=10, gamma=0.001;, score=0.679 total time=   1.4s
# [CV 5/5] END .................C=10, gamma=0.001;, score=0.680 total time=   1.3s
# [CV 1/5] END ..................C=10, gamma=0.01;, score=0.693 total time=   1.2s
# [CV 2/5] END ..................C=10, gamma=0.01;, score=0.717 total time=   1.2s
# [CV 3/5] END ..................C=10, gamma=0.01;, score=0.711 total time=   1.2s
# [CV 4/5] END ..................C=10, gamma=0.01;, score=0.711 total time=   1.2s
# [CV 5/5] END ..................C=10, gamma=0.01;, score=0.713 total time=   1.2s
# [CV 1/5] END ...................C=10, gamma=0.1;, score=0.722 total time=   1.2s
# [CV 2/5] END ...................C=10, gamma=0.1;, score=0.718 total time=   1.2s
# [CV 3/5] END ...................C=10, gamma=0.1;, score=0.718 total time=   1.2s
# [CV 4/5] END ...................C=10, gamma=0.1;, score=0.729 total time=   1.2s
# [CV 5/5] END ...................C=10, gamma=0.1;, score=0.727 total time=   1.3s
# [CV 1/5] END .....................C=10, gamma=1;, score=0.660 total time=   1.6s
# [CV 2/5] END .....................C=10, gamma=1;, score=0.649 total time=   1.6s
# [CV 3/5] END .....................C=10, gamma=1;, score=0.662 total time=   1.6s
# [CV 4/5] END .....................C=10, gamma=1;, score=0.680 total time=   1.6s
# [CV 5/5] END .....................C=10, gamma=1;, score=0.663 total time=   1.6s
# [CV 1/5] END ................C=100, gamma=scale;, score=0.736 total time=   1.6s
# [CV 2/5] END ................C=100, gamma=scale;, score=0.725 total time=   1.6s
# [CV 3/5] END ................C=100, gamma=scale;, score=0.741 total time=   1.6s
# [CV 4/5] END ................C=100, gamma=scale;, score=0.741 total time=   1.6s
# [CV 5/5] END ................C=100, gamma=scale;, score=0.741 total time=   1.6s
# [CV 1/5] END ................C=100, gamma=0.001;, score=0.694 total time=   1.3s
# [CV 2/5] END ................C=100, gamma=0.001;, score=0.710 total time=   1.4s
# [CV 3/5] END ................C=100, gamma=0.001;, score=0.700 total time=   1.3s
# [CV 4/5] END ................C=100, gamma=0.001;, score=0.717 total time=   1.3s
# [CV 5/5] END ................C=100, gamma=0.001;, score=0.703 total time=   1.3s
# [CV 1/5] END .................C=100, gamma=0.01;, score=0.726 total time=   1.3s
# [CV 2/5] END .................C=100, gamma=0.01;, score=0.725 total time=   1.3s
# [CV 3/5] END .................C=100, gamma=0.01;, score=0.730 total time=   1.3s
# [CV 4/5] END .................C=100, gamma=0.01;, score=0.721 total time=   1.3s
# [CV 5/5] END .................C=100, gamma=0.01;, score=0.733 total time=   1.3s
# [CV 1/5] END ..................C=100, gamma=0.1;, score=0.729 total time=   1.8s
# [CV 2/5] END ..................C=100, gamma=0.1;, score=0.725 total time=   1.8s
# [CV 3/5] END ..................C=100, gamma=0.1;, score=0.728 total time=   1.8s
# [CV 4/5] END ..................C=100, gamma=0.1;, score=0.738 total time=   1.8s
# [CV 5/5] END ..................C=100, gamma=0.1;, score=0.735 total time=   1.8s
# [CV 1/5] END ....................C=100, gamma=1;, score=0.650 total time=   2.8s
# [CV 2/5] END ....................C=100, gamma=1;, score=0.645 total time=   2.7s
# [CV 3/5] END ....................C=100, gamma=1;, score=0.654 total time=   2.9s
# [CV 4/5] END ....................C=100, gamma=1;, score=0.672 total time=   3.1s
# [CV 5/5] END ....................C=100, gamma=1;, score=0.654 total time=   2.9s
# Best parameters: {'C': 100, 'gamma': 'scale'}
# Best cross-validation score: 0.74
#               precision    recall  f1-score   support
#
#   com_doenca       0.70      0.74      0.72       958
#   sem_doenca       0.79      0.75      0.77      1216
#
#     accuracy                           0.75      2174
#    macro avg       0.74      0.74      0.74      2174
# weighted avg       0.75      0.75      0.75      2174

# %%
joblib.dump(best_model, 'best_svm_model_binary.joblib')
# Out:
# ['best_svm_model_binary.joblib']

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from skimage.feature import graycomatrix, graycoprops
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import joblib

def get_haralick_descriptors(image_pil_color):
    # Convert PIL image to NumPy array
    array = np.array(image_pil_color)
    
    # Convert BGR to RGB
    image_rgb = cv2.cvtColor(array, cv2.COLOR_BGR2RGB)
    
    # Convert RGB to grayscale
    image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)
    
    # Reduce image to 16 gray levels
    image_gray //= 16
    
    # Define distances and angle
    distances = [1, 2, 4, 8, 16, 31]
    angle = 0
    
    features = []
    
    # Compute GLCM and Haralick features
    for d in distances:
        glcm = graycomatrix(image_gray, distances=[d], angles=[angle], levels=16, symmetric=True, normed=True)
        contrast = graycoprops(glcm, 'contrast')[0, 0]
        homogeneity = graycoprops(glcm, 'homogeneity')[0, 0]
        entropy = -np.sum(glcm * np.log2(glcm + np.finfo(float).eps))
        
        # Collect the features
        features.extend([contrast, homogeneity, entropy])
    
    return features

# Base directory containing subdirectories of images
base_dir = "sub_images"

# List to hold image data and labels
features = []
labels = []

# Iterate through each subdirectory in the base directory
for subdir in os.listdir(base_dir):
    subdir_path = os.path.join(base_dir, subdir)
    
    # Check if it's a directory
    if os.path.isdir(subdir_path):
        # Process each image in the subdirectory
        for filename in os.listdir(subdir_path):
            if filename.endswith(".png"):
                # Construct full file path
                file_path = os.path.join(subdir_path, filename)
                # Open the image with PIL
                with Image.open(file_path) as img:
                    # Extract Haralick descriptors
                    img_features = get_haralick_descriptors(img)
                    
                    # Append the processed features and label
                    features.append(img_features)
                    labels.append(subdir)  # Use subdir as label

# Convert list to NumPy arrays for machine learning processing
features = np.array(features)
labels = np.array(labels)

# Split data into 80% train and 20% test subsets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.20, random_state=42)

# Optional: scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create the SVM model with balanced class weights
model = svm.SVC(kernel='rbf', gamma='scale', class_weight='balanced')
model.fit(X_train_scaled, y_train)

# Save the model
joblib.dump(model, 'svm_haralick_model_six_categories.joblib')


# Load the model
loaded_model = joblib.load('svm_haralick_model_six_categories.joblib')

# Use the loaded model to make predictions
y_pred = loaded_model.predict(X_test_scaled)

# Print classification report
print("Classification report for classifier %s:\n%s\n"
      % (model, classification_report(y_test, y_pred)))
# Out:
# Classification report for classifier SVC(class_weight='balanced'):
#                                      precision    recall  f1-score   support
#
#                               ASC-H       0.16      0.32      0.21       179
#                              ASC-US       0.14      0.41      0.21       126
#                                HSIL       0.54      0.41      0.47       342
#                                LSIL       0.21      0.34      0.26       277
# Negative for intraepithelial lesion       0.86      0.40      0.54      1216
#                                 SCC       0.14      0.74      0.23        34
#
#                            accuracy                           0.39      2174
#                           macro avg       0.34      0.44      0.32      2174
#                        weighted avg       0.62      0.39      0.44      2174

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Define the parameter grid to search
param_grid = {
    'C': [0.1, 1, 10, 100],  # Regularization parameter
    'gamma': ['scale', 0.001, 0.01, 0.1, 1],  # Kernel coefficient for 'rbf'
}

# Create a GridSearchCV object
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy', verbose=3)

# Fit GridSearchCV
grid_search.fit(X_train_scaled, y_train)

# Best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))

# Retrain model with best parameters
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_scaled)

# Evaluate the classifier performance on the test set
print(classification_report(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END ................C=0.1, gamma=scale;, score=0.296 total time=   2.7s
# [CV 2/5] END ................C=0.1, gamma=scale;, score=0.328 total time=   2.7s
# [CV 3/5] END ................C=0.1, gamma=scale;, score=0.335 total time=   2.7s
# [CV 4/5] END ................C=0.1, gamma=scale;, score=0.336 total time=   2.7s
# [CV 5/5] END ................C=0.1, gamma=scale;, score=0.352 total time=   2.7s
# [CV 1/5] END ................C=0.1, gamma=0.001;, score=0.137 total time=   3.1s
# [CV 2/5] END ................C=0.1, gamma=0.001;, score=0.139 total time=   3.1s
# [CV 3/5] END ................C=0.1, gamma=0.001;, score=0.090 total time=   3.1s
# [CV 4/5] END ................C=0.1, gamma=0.001;, score=0.099 total time=   3.1s
# [CV 5/5] END ................C=0.1, gamma=0.001;, score=0.173 total time=   3.1s
# [CV 1/5] END .................C=0.1, gamma=0.01;, score=0.282 total time=   2.8s
# [CV 2/5] END .................C=0.1, gamma=0.01;, score=0.311 total time=   2.8s
# [CV 3/5] END .................C=0.1, gamma=0.01;, score=0.334 total time=   2.8s
# [CV 4/5] END .................C=0.1, gamma=0.01;, score=0.321 total time=   2.8s
# [CV 5/5] END .................C=0.1, gamma=0.01;, score=0.326 total time=   2.8s
# [CV 1/5] END ..................C=0.1, gamma=0.1;, score=0.304 total time=   2.6s
# [CV 2/5] END ..................C=0.1, gamma=0.1;, score=0.330 total time=   2.7s
# [CV 3/5] END ..................C=0.1, gamma=0.1;, score=0.341 total time=   2.7s
# [CV 4/5] END ..................C=0.1, gamma=0.1;, score=0.340 total time=   2.6s
# [CV 5/5] END ..................C=0.1, gamma=0.1;, score=0.352 total time=   2.7s
# [CV 1/5] END ....................C=0.1, gamma=1;, score=0.298 total time=   3.1s
# [CV 2/5] END ....................C=0.1, gamma=1;, score=0.322 total time=   3.1s
# [CV 3/5] END ....................C=0.1, gamma=1;, score=0.302 total time=   3.1s
# [CV 4/5] END ....................C=0.1, gamma=1;, score=0.328 total time=   3.1s
# [CV 5/5] END ....................C=0.1, gamma=1;, score=0.330 total time=   3.1s
# [CV 1/5] END ..................C=1, gamma=scale;, score=0.355 total time=   2.4s
# [CV 2/5] END ..................C=1, gamma=scale;, score=0.378 total time=   2.4s
# [CV 3/5] END ..................C=1, gamma=scale;, score=0.380 total time=   2.4s
# [CV 4/5] END ..................C=1, gamma=scale;, score=0.376 total time=   2.4s
# [CV 5/5] END ..................C=1, gamma=scale;, score=0.381 total time=   2.4s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.286 total time=   2.9s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.303 total time=   2.9s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.310 total time=   2.9s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.305 total time=   2.8s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=0.322 total time=   2.9s
# [CV 1/5] END ...................C=1, gamma=0.01;, score=0.327 total time=   2.5s
# [CV 2/5] END ...................C=1, gamma=0.01;, score=0.355 total time=   2.5s
# [CV 3/5] END ...................C=1, gamma=0.01;, score=0.367 total time=   2.6s
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.346 total time=   2.6s
# [CV 5/5] END ...................C=1, gamma=0.01;, score=0.369 total time=   2.6s
# [CV 1/5] END ....................C=1, gamma=0.1;, score=0.361 total time=   2.4s
# [CV 2/5] END ....................C=1, gamma=0.1;, score=0.381 total time=   2.4s
# [CV 3/5] END ....................C=1, gamma=0.1;, score=0.384 total time=   2.4s
# [CV 4/5] END ....................C=1, gamma=0.1;, score=0.381 total time=   2.4s
# [CV 5/5] END ....................C=1, gamma=0.1;, score=0.390 total time=   2.4s
# [CV 1/5] END ......................C=1, gamma=1;, score=0.393 total time=   2.5s
# [CV 2/5] END ......................C=1, gamma=1;, score=0.418 total time=   2.5s
# [CV 3/5] END ......................C=1, gamma=1;, score=0.417 total time=   2.7s
# [CV 4/5] END ......................C=1, gamma=1;, score=0.416 total time=   3.5s
# [CV 5/5] END ......................C=1, gamma=1;, score=0.411 total time=   4.8s
# [CV 1/5] END .................C=10, gamma=scale;, score=0.399 total time=   6.9s
# [CV 2/5] END .................C=10, gamma=scale;, score=0.420 total time=   5.1s
# [CV 3/5] END .................C=10, gamma=scale;, score=0.419 total time=   4.1s
# [CV 4/5] END .................C=10, gamma=scale;, score=0.416 total time=   4.4s
# [CV 5/5] END .................C=10, gamma=scale;, score=0.437 total time=   4.6s
# [CV 1/5] END .................C=10, gamma=0.001;, score=0.349 total time=   7.3s
# [CV 2/5] END .................C=10, gamma=0.001;, score=0.351 total time=   7.3s
# [CV 3/5] END .................C=10, gamma=0.001;, score=0.377 total time=   7.5s
# [CV 4/5] END .................C=10, gamma=0.001;, score=0.355 total time=   6.3s
# [CV 5/5] END .................C=10, gamma=0.001;, score=0.374 total time=   6.1s
# [CV 1/5] END ..................C=10, gamma=0.01;, score=0.381 total time=   6.7s
# [CV 2/5] END ..................C=10, gamma=0.01;, score=0.380 total time=   5.4s
# [CV 3/5] END ..................C=10, gamma=0.01;, score=0.396 total time=   7.4s
# [CV 4/5] END ..................C=10, gamma=0.01;, score=0.375 total time=   6.0s
# [CV 5/5] END ..................C=10, gamma=0.01;, score=0.400 total time=   5.2s
# [CV 1/5] END ...................C=10, gamma=0.1;, score=0.411 total time=   4.5s
# [CV 2/5] END ...................C=10, gamma=0.1;, score=0.416 total time=   4.5s
# [CV 3/5] END ...................C=10, gamma=0.1;, score=0.432 total time=   4.5s
# [CV 4/5] END ...................C=10, gamma=0.1;, score=0.416 total time=   4.5s
# [CV 5/5] END ...................C=10, gamma=0.1;, score=0.434 total time=   4.6s
# [CV 1/5] END .....................C=10, gamma=1;, score=0.457 total time=   4.9s
# [CV 2/5] END .....................C=10, gamma=1;, score=0.466 total time=   4.8s
# [CV 3/5] END .....................C=10, gamma=1;, score=0.489 total time=   5.3s
# [CV 4/5] END .....................C=10, gamma=1;, score=0.476 total time=   6.6s
# [CV 5/5] END .....................C=10, gamma=1;, score=0.474 total time=   7.4s
# [CV 1/5] END ................C=100, gamma=scale;, score=0.428 total time=   6.0s
# [CV 2/5] END ................C=100, gamma=scale;, score=0.438 total time=   6.0s
# [CV 3/5] END ................C=100, gamma=scale;, score=0.451 total time=   6.3s
# [CV 4/5] END ................C=100, gamma=scale;, score=0.443 total time=   8.8s
# [CV 5/5] END ................C=100, gamma=scale;, score=0.467 total time=   8.5s
# [CV 1/5] END ................C=100, gamma=0.001;, score=0.382 total time=   5.7s
# [CV 2/5] END ................C=100, gamma=0.001;, score=0.381 total time=   6.1s
# [CV 3/5] END ................C=100, gamma=0.001;, score=0.396 total time=   6.2s
# [CV 4/5] END ................C=100, gamma=0.001;, score=0.378 total time=   5.8s
# [CV 5/5] END ................C=100, gamma=0.001;, score=0.400 total time=   6.2s
# [CV 1/5] END .................C=100, gamma=0.01;, score=0.399 total time=   5.3s
# [CV 2/5] END .................C=100, gamma=0.01;, score=0.421 total time=   5.2s
# [CV 3/5] END .................C=100, gamma=0.01;, score=0.436 total time=   5.5s
# [CV 4/5] END .................C=100, gamma=0.01;, score=0.430 total time=   5.0s
# [CV 5/5] END .................C=100, gamma=0.01;, score=0.441 total time=   5.2s
# [CV 1/5] END ..................C=100, gamma=0.1;, score=0.434 total time=   6.1s
# [CV 2/5] END ..................C=100, gamma=0.1;, score=0.457 total time=   6.2s
# [CV 3/5] END ..................C=100, gamma=0.1;, score=0.450 total time=   6.0s
# [CV 4/5] END ..................C=100, gamma=0.1;, score=0.459 total time=   6.5s
# [CV 5/5] END ..................C=100, gamma=0.1;, score=0.460 total time=   9.8s
# [CV 1/5] END ....................C=100, gamma=1;, score=0.493 total time=   7.6s
# [CV 2/5] END ....................C=100, gamma=1;, score=0.508 total time=   6.7s
# [CV 3/5] END ....................C=100, gamma=1;, score=0.515 total time=   5.8s
# [CV 4/5] END ....................C=100, gamma=1;, score=0.512 total time=   5.8s
# [CV 5/5] END ....................C=100, gamma=1;, score=0.505 total time=   6.2s
# Best parameters: {'C': 100, 'gamma': 1}
# Best cross-validation score: 0.51
#                                      precision    recall  f1-score   support
#
#                               ASC-H       0.18      0.23      0.20       179
#                              ASC-US       0.19      0.17      0.18       126
#                                HSIL       0.47      0.45      0.46       342
#                                LSIL       0.27      0.25      0.26       277
# Negative for intraepithelial lesion       0.71      0.71      0.71      1216
#                                 SCC       0.10      0.06      0.07        34
#
#                            accuracy                           0.53      2174
#                           macro avg       0.32      0.31      0.31      2174
#                        weighted avg       0.53      0.53      0.53      2174

# %%
joblib.dump(best_model, 'best_svm_model_6_catgoties.joblib')
# Out:
# ['best_svm_model_6_catgoties.joblib']
